# %%
import pandas as pd
NBA_Games=pd.read_csv("C:/Users/trent/OneDrive/Documents/Repositories/NBA-Correlation/data/NBA_games.csv")
NBA_Games.head()
# Out:
#            CITY              TEAM_NAME     TEAM_ID  NICKNAME       STATE  \
# 0       Indiana         Indiana Pacers  1610612754    Pacers     Indiana
# 1       Chicago          Chicago Bulls  1610612741     Bulls    Illinois
# 2       Houston        Houston Rockets  1610612745   Rockets       Texas
# 3   New Orleans   New Orleans Pelicans  1610612740  Pelicans   Louisiana
# 4  Golden State  Golden State Warriors  1610612744  Warriors  California
#
#    YEAR_FOUNDED  SEASON_ID TEAM_ABBREVIATION   GAME_ID  GAME_DATE  ... DREB  \
# 0          1976      12013               IND  11300002  10/5/2013  ...   27
# 1          1966      12013               CHI  11300002  10/5/2013  ...   39
# 2          1967      12013               HOU  11300003  10/5/2013  ...   30
# 3          2002      12013               NOP  11300003  10/5/2013  ...   21
# 4          1946      12013               GSW  11300004  10/5/2013  ...   38
#
#   REB  AST  STL  BLK  TOV  PF  PLUS_MINUS  GM  POINT_DIFF
# 0  38   15   12    8   15  23        -6.0  49         6.0
# 1  56   20    5   10   23  25         6.0  54         6.0
# 2  35   24    9    4   22  27        -1.0  76         1.0
# 3  33   17   12    4   15  32         1.0  74         1.0
# 4  52   21   13    5   23  31        -9.0  60         9.0
#
# [5 rows x 34 columns]

# %%
NBA_Games.dtypes
# Out:
# CITY                  object
# TEAM_NAME             object
# TEAM_ID                int64
# NICKNAME              object
# STATE                 object
# YEAR_FOUNDED           int64
# SEASON_ID              int64
# TEAM_ABBREVIATION     object
# GAME_ID                int64
# GAME_DATE             object
# MATCHUP               object
# WL                    object
# MIN                    int64
# PTS                    int64
# FGM                    int64
# FGA                    int64
# FG_PCT               float64
# FG3M                   int64
# FG3A                   int64
# FG3_PCT              float64
# FTM                    int64
# FTA                    int64
# FT_PCT               float64
# OREB                   int64
# DREB                   int64
# REB                    int64
# AST                    int64
# STL                    int64
# BLK                    int64
# TOV                    int64
# PF                     int64
# PLUS_MINUS           float64
# GM                     int64
# POINT_DIFF           float64
# dtype: object

# %%
dummy=pd.get_dummies(NBA_Games, columns=['WL'])

# %%
dummy.columns
# Out:
# Index(['CITY', 'TEAM_NAME', 'TEAM_ID', 'NICKNAME', 'STATE', 'YEAR_FOUNDED',
#        'SEASON_ID', 'TEAM_ABBREVIATION', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM',
#        'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV',
#        'PF', 'PLUS_MINUS', 'GM', 'POINT_DIFF', 'WL_L', 'WL_W'],
#       dtype='object')

# %%
NBA_Games=pd.concat([NBA_Games, dummy['WL_W']], axis=1)
NBA_Games.head()
# Out:
#            CITY              TEAM_NAME     TEAM_ID  NICKNAME       STATE  \
# 0       Indiana         Indiana Pacers  1610612754    Pacers     Indiana
# 1       Chicago          Chicago Bulls  1610612741     Bulls    Illinois
# 2       Houston        Houston Rockets  1610612745   Rockets       Texas
# 3   New Orleans   New Orleans Pelicans  1610612740  Pelicans   Louisiana
# 4  Golden State  Golden State Warriors  1610612744  Warriors  California
#
#    YEAR_FOUNDED  SEASON_ID TEAM_ABBREVIATION   GAME_ID  GAME_DATE  ... REB  \
# 0          1976      12013               IND  11300002  10/5/2013  ...  38
# 1          1966      12013               CHI  11300002  10/5/2013  ...  56
# 2          1967      12013               HOU  11300003  10/5/2013  ...  35
# 3          2002      12013               NOP  11300003  10/5/2013  ...  33
# 4          1946      12013               GSW  11300004  10/5/2013  ...  52
#
#   AST  STL  BLK  TOV  PF  PLUS_MINUS  GM  POINT_DIFF   WL_W
# 0  15   12    8   15  23        -6.0  49         6.0  False
# 1  20    5   10   23  25         6.0  54         6.0   True
# 2  24    9    4   22  27        -1.0  76         1.0  False
# 3  17   12    4   15  32         1.0  74         1.0   True
# 4  21   13    5   23  31        -9.0  60         9.0  False
#
# [5 rows x 35 columns]

# %%
NBA_Games.rename(columns={'WL_W':'WIN'}, inplace=True)
NBA_Games.head()
# Out:
#            CITY              TEAM_NAME     TEAM_ID  NICKNAME       STATE  \
# 0       Indiana         Indiana Pacers  1610612754    Pacers     Indiana
# 1       Chicago          Chicago Bulls  1610612741     Bulls    Illinois
# 2       Houston        Houston Rockets  1610612745   Rockets       Texas
# 3   New Orleans   New Orleans Pelicans  1610612740  Pelicans   Louisiana
# 4  Golden State  Golden State Warriors  1610612744  Warriors  California
#
#    YEAR_FOUNDED  SEASON_ID TEAM_ABBREVIATION   GAME_ID  GAME_DATE  ... REB  \
# 0          1976      12013               IND  11300002  10/5/2013  ...  38
# 1          1966      12013               CHI  11300002  10/5/2013  ...  56
# 2          1967      12013               HOU  11300003  10/5/2013  ...  35
# 3          2002      12013               NOP  11300003  10/5/2013  ...  33
# 4          1946      12013               GSW  11300004  10/5/2013  ...  52
#
#   AST  STL  BLK  TOV  PF  PLUS_MINUS  GM  POINT_DIFF    WIN
# 0  15   12    8   15  23        -6.0  49         6.0  False
# 1  20    5   10   23  25         6.0  54         6.0   True
# 2  24    9    4   22  27        -1.0  76         1.0  False
# 3  17   12    4   15  32         1.0  74         1.0   True
# 4  21   13    5   23  31        -9.0  60         9.0  False
#
# [5 rows x 35 columns]

# %%
NBA_Games['GAME_DATE'].dtype
# Out:
# dtype('O')

# %%
import datetime
NBA_Games['GAME_DATE']=pd.to_datetime(NBA_Games['GAME_DATE'])
NBA_Games['GAME_DATE'].head()
# Out:
# 0   2013-10-05
# 1   2013-10-05
# 2   2013-10-05
# 3   2013-10-05
# 4   2013-10-05
# Name: GAME_DATE, dtype: datetime64[ns]

# %%
NBA_Games.describe()
# Out:
#             TEAM_ID  YEAR_FOUNDED     SEASON_ID       GAME_ID  \
# count  1.777900e+04  17779.000000  17779.000000  1.777900e+04
# mean   1.610613e+09   1969.512402  22692.567130  1.183556e+08
# min    1.610613e+09   1946.000000  12013.000000  1.130000e+07
# 25%    1.610613e+09   1949.000000  22014.000000  2.140029e+07
# 50%    1.610613e+09   1970.000000  22015.000000  2.160015e+07
# 75%    1.610613e+09   1980.000000  22017.000000  2.180007e+07
# max    1.610613e+09   2002.000000  42018.000000  1.621900e+09
# std    8.676904e+00     16.503036   5534.895754  3.655546e+08
#
#                            GAME_DATE           MIN           PTS  \
# count                          17779  17779.000000  17779.000000
# mean   2016-05-20 08:19:58.717587968    239.157433    102.423421
# min              2013-03-09 00:00:00    170.000000     47.000000
# 25%              2014-12-04 00:00:00    239.000000     93.000000
# 50%              2016-03-26 00:00:00    240.000000    103.000000
# 75%              2017-12-25 00:00:00    241.000000    112.000000
# max              2019-07-15 00:00:00    341.000000    168.000000
# std                              NaN     12.496399     13.598390
#
#                 FGM           FGA        FG_PCT  ...          DREB  \
# count  17779.000000  17779.000000  17779.000000  ...  17779.000000
# mean      37.944035     83.974127      0.452485  ...     32.817988
# min       15.000000     46.000000      0.217000  ...     11.000000
# 25%       34.000000     79.000000      0.414000  ...     29.000000
# 50%       38.000000     84.000000      0.452000  ...     33.000000
# 75%       42.000000     89.000000      0.489000  ...     37.000000
# max       61.000000    129.000000      0.684000  ...     56.000000
# std        5.646131      8.337715      0.056357  ...      5.574817
#
#                 REB           AST           STL           BLK           TOV  \
# count  17779.000000  17779.000000  17779.000000  17779.000000  17779.000000
# mean      43.215535     22.082851      7.785309      4.819225     13.963890
# min       17.000000      2.000000      0.000000      0.000000      2.000000
# 25%       39.000000     18.000000      6.000000      3.000000     11.000000
# 50%       43.000000     22.000000      8.000000      5.000000     14.000000
# 75%       48.000000     26.000000     10.000000      6.000000     16.000000
# max       81.000000     47.000000     21.000000     19.000000     35.000000
# std        6.709445      5.463359      2.962259      2.520843      4.024721
#
#                  PF    PLUS_MINUS            GM    POINT_DIFF
# count  17779.000000  17779.000000  17779.000000  17779.000000
# mean      20.673885     -0.002666     64.479386     11.187525
# min        7.000000    -61.000000     29.000000    -42.000000
# 25%       18.000000     -9.000000     58.000000      5.000000
# 50%       20.000000      0.000000     64.000000      9.000000
# 75%       24.000000      9.000000     71.000000     16.000000
# max       45.000000     61.000000    112.000000     61.000000
# std        4.563555     13.889791      9.140930      8.254579
#
# [8 rows x 27 columns]

# %%
NBA_Games.describe(include='all')
# Out:
#                CITY              TEAM_NAME       TEAM_ID  NICKNAME  \
# count         17779                  17779  1.777900e+04     17779
# unique           29                     30           NaN        30
# top     Los Angeles  Golden State Warriors           NaN  Warriors
# freq            816                    688           NaN       688
# mean            NaN                    NaN  1.610613e+09       NaN
# min             NaN                    NaN  1.610613e+09       NaN
# 25%             NaN                    NaN  1.610613e+09       NaN
# 50%             NaN                    NaN  1.610613e+09       NaN
# 75%             NaN                    NaN  1.610613e+09       NaN
# max             NaN                    NaN  1.610613e+09       NaN
# std             NaN                    NaN  8.676904e+00       NaN
#
#              STATE  YEAR_FOUNDED     SEASON_ID TEAM_ABBREVIATION  \
# count        17779  17779.000000  17779.000000             17779
# unique          23           NaN           NaN                30
# top     California           NaN           NaN               GSW
# freq          2068           NaN           NaN               688
# mean           NaN   1969.512402  22692.567130               NaN
# min            NaN   1946.000000  12013.000000               NaN
# 25%            NaN   1949.000000  22014.000000               NaN
# 50%            NaN   1970.000000  22015.000000               NaN
# 75%            NaN   1980.000000  22017.000000               NaN
# max            NaN   2002.000000  42018.000000               NaN
# std            NaN     16.503036   5534.895754               NaN
#
#              GAME_ID                      GAME_DATE  ...           REB  \
# count   1.777900e+04                          17779  ...  17779.000000
# unique           NaN                            NaN  ...           NaN
# top              NaN                            NaN  ...           NaN
# freq             NaN                            NaN  ...           NaN
# mean    1.183556e+08  2016-05-20 08:19:58.717587968  ...     43.215535
# min     1.130000e+07            2013-03-09 00:00:00  ...     17.000000
# 25%     2.140029e+07            2014-12-04 00:00:00  ...     39.000000
# 50%     2.160015e+07            2016-03-26 00:00:00  ...     43.000000
# 75%     2.180007e+07            2017-12-25 00:00:00  ...     48.000000
# max     1.621900e+09            2019-07-15 00:00:00  ...     81.000000
# std     3.655546e+08                            NaN  ...      6.709445
#
#                  AST           STL           BLK           TOV            PF  \
# count   17779.000000  17779.000000  17779.000000  17779.000000  17779.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       22.082851      7.785309      4.819225     13.963890     20.673885
# min         2.000000      0.000000      0.000000      2.000000      7.000000
# 25%        18.000000      6.000000      3.000000     11.000000     18.000000
# 50%        22.000000      8.000000      5.000000     14.000000     20.000000
# 75%        26.000000     10.000000      6.000000     16.000000     24.000000
# max        47.000000     21.000000     19.000000     35.000000     45.000000
# std         5.463359      2.962259      2.520843      4.024721      4.563555
#
#           PLUS_MINUS            GM    POINT_DIFF    WIN
# count   17779.000000  17779.000000  17779.000000  17779
# unique           NaN           NaN           NaN      2
# top              NaN           NaN           NaN  False
# freq             NaN           NaN           NaN   8890
# mean       -0.002666     64.479386     11.187525    NaN
# min       -61.000000     29.000000    -42.000000    NaN
# 25%        -9.000000     58.000000      5.000000    NaN
# 50%         0.000000     64.000000      9.000000    NaN
# 75%         9.000000     71.000000     16.000000    NaN
# max        61.000000    112.000000     61.000000    NaN
# std        13.889791      9.140930      8.254579    NaN
#
# [11 rows x 35 columns]

# %%
NBA_Games['PTS'].describe()
# Out:
# count    17779.000000
# mean       102.423421
# std         13.598390
# min         47.000000
# 25%         93.000000
# 50%        103.000000
# 75%        112.000000
# max        168.000000
# Name: PTS, dtype: float64

# %%
NBA_Games['FGM'].mean()
# Out:
# np.float64(37.94403509758704)

# %%
NBA_Games['FGM'].median()
# Out:
# np.float64(38.0)

# %%
NBA_Games['FGM'].std()
# Out:
# np.float64(5.646131461395677)

# %%
NBA_Games.groupby(['WL']).mean(numeric_only=True)
# Out:
#          TEAM_ID  YEAR_FOUNDED     SEASON_ID       GAME_ID         MIN  \
# WL
# L   1.610613e+09   1969.210461  22692.529246  1.184346e+08  239.146119
# W   1.610613e+09   1969.814377  22692.605017  1.182767e+08  239.168748
#
#            PTS        FGM        FGA    FG_PCT      FG3M  ...        REB  \
# WL                                                        ...
# L    96.821485  35.995388  84.260855  0.427531  8.182790  ...  41.500562
# W   108.025987  39.892901  83.687366  0.477441  9.892564  ...  44.930701
#
#           AST       STL       BLK        TOV         PF  PLUS_MINUS  \
# WL
# L   20.507312  7.388189  4.405287  14.407649  21.143982  -11.186862
# W   23.658567  8.182473  5.233210  13.520081  20.203735   11.182788
#
#            GM  POINT_DIFF  WIN
# WL
# L   60.826097   11.175028  0.0
# W   68.133086   11.200022  1.0
#
# [2 rows x 27 columns]

# %%
NBA_Games.groupby(['WL'])['PTS'].mean()
# Out:
# WL
# L     96.821485
# W    108.025987
# Name: PTS, dtype: float64

# %%
NBA_Games['GAME_DATE'].describe()
# Out:
# count                            17779
# mean     2016-05-20 08:19:58.717587968
# min                2013-03-09 00:00:00
# 25%                2014-12-04 00:00:00
# 50%                2016-03-26 00:00:00
# 75%                2017-12-25 00:00:00
# max                2019-07-15 00:00:00
# Name: GAME_DATE, dtype: object

# %%
NBA_Games.hist(column='PTS')
# Out:
# array([[<Axes: title={'center': 'PTS'}>]], dtype=object)

# %%
NBA_Games.hist(column='PTS', bins=20)
# Out:
# array([[<Axes: title={'center': 'PTS'}>]], dtype=object)

# %%
NBA_Games.hist(column='PTS', bins=20, rwidth=0.9)
# Out:
# array([[<Axes: title={'center': 'PTS'}>]], dtype=object)

# %%
NBA_Games.to_csv("C:/Users/trent/OneDrive/Documents/Repositories/NBA-Correlation/data/NBA_games2.csv", index=False)

# %%
import pandas as pd
NBA_Games=pd.read_csv("C:/Users/trent/OneDrive/Documents/Repositories/NBA-Correlation/data/NBA_games2.csv")
NBA_Games.head()
# Out:
#            CITY              TEAM_NAME     TEAM_ID  NICKNAME       STATE  \
# 0       Indiana         Indiana Pacers  1610612754    Pacers     Indiana
# 1       Chicago          Chicago Bulls  1610612741     Bulls    Illinois
# 2       Houston        Houston Rockets  1610612745   Rockets       Texas
# 3   New Orleans   New Orleans Pelicans  1610612740  Pelicans   Louisiana
# 4  Golden State  Golden State Warriors  1610612744  Warriors  California
#
#    YEAR_FOUNDED  SEASON_ID TEAM_ABBREVIATION   GAME_ID   GAME_DATE  ... REB  \
# 0          1976      12013               IND  11300002  2013-10-05  ...  38
# 1          1966      12013               CHI  11300002  2013-10-05  ...  56
# 2          1967      12013               HOU  11300003  2013-10-05  ...  35
# 3          2002      12013               NOP  11300003  2013-10-05  ...  33
# 4          1946      12013               GSW  11300004  2013-10-05  ...  52
#
#   AST  STL  BLK  TOV  PF  PLUS_MINUS  GM  POINT_DIFF    WIN
# 0  15   12    8   15  23        -6.0  49         6.0  False
# 1  20    5   10   23  25         6.0  54         6.0   True
# 2  24    9    4   22  27        -1.0  76         1.0  False
# 3  17   12    4   15  32         1.0  74         1.0   True
# 4  21   13    5   23  31        -9.0  60         9.0  False
#
# [5 rows x 35 columns]

# %%
NBA_Games['FG_PCT'].describe()
# Out:
# count    17779.000000
# mean         0.452485
# std          0.056357
# min          0.217000
# 25%          0.414000
# 50%          0.452000
# 75%          0.489000
# max          0.684000
# Name: FG_PCT, dtype: float64

# %%
NBA_Games['FG3_PCT'].describe()
# Out:
# count    17779.000000
# mean         0.350610
# std          0.099538
# min          0.000000
# 25%          0.286000
# 50%          0.350000
# 75%          0.417000
# max          0.842000
# Name: FG3_PCT, dtype: float64

# %%
NBA_Games.hist(column=['FG_PCT','FG3_PCT'], bins=20, sharex=True, sharey=True)
# Out:
# array([[<Axes: title={'center': 'FG_PCT'}>,
#         <Axes: title={'center': 'FG3_PCT'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

NBA_Games[['FG_PCT','FG3_PCT']].plot.hist(alpha=0.3, bins=20)
plt.xlabel('Field Goal Percentage')
plt.ylabel('Frequency')
plt.title("Distributions of Field Goal Percentages", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Distributions of Field Goal Percentages')

# %%
NBA_Games.hist(by='WL', column='FG_PCT', color='red', bins=15, sharex=True, sharey=True)
# Out:
# array([<Axes: title={'center': 'L'}>, <Axes: title={'center': 'W'}>],
#       dtype=object)

# %%
import datetime
NBA_Games['GAME_DATE']=pd.to_datetime(NBA_Games['GAME_DATE'])
NBA_Games['GAME_DATE'].head()
# Out:
# 0   2013-10-05
# 1   2013-10-05
# 2   2013-10-05
# 3   2013-10-05
# 4   2013-10-05
# Name: GAME_DATE, dtype: datetime64[ns]

# %%
Pistons_Games=NBA_Games[(NBA_Games.NICKNAME == 'Pistons')&(NBA_Games.SEASON_ID==22017)& (NBA_Games.GAME_DATE>='2017-10-17')]
display(Pistons_Games)
# Out:
#           CITY        TEAM_NAME     TEAM_ID NICKNAME     STATE  YEAR_FOUNDED  \
# 10919  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 10950  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 10971  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 10990  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 11019  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# ...        ...              ...         ...      ...       ...           ...
# 13094  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 13117  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 13150  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 13160  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
# 13199  Detroit  Detroit Pistons  1610612765  Pistons  Michigan          1948
#
#        SEASON_ID TEAM_ABBREVIATION   GAME_ID  GAME_DATE  ... REB AST  STL  \
# 10919      22017               DET  21700003 2017-10-18  ...  47  24   14
# 10950      22017               DET  21700020 2017-10-20  ...  33  19   12
# 10971      22017               DET  21700030 2017-10-21  ...  43  21    5
# 10990      22017               DET  21700041 2017-10-23  ...  39  14    5
# 11019      22017               DET  21700056 2017-10-25  ...  47  32    7
# ...          ...               ...       ...        ...  ...  ..  ..  ...
# 13094      22017               DET  21701169 2018-04-04  ...  42  30    4
# 13117      22017               DET  21701181 2018-04-06  ...  49  24    6
# 13150      22017               DET  21701199 2018-04-08  ...  38  30   10
# 13160      22017               DET  21701204 2018-04-09  ...  33  22    7
# 13199      22017               DET  21701224 2018-04-11  ...  47  27   12
#
#        BLK  TOV  PF  PLUS_MINUS  GM  POINT_DIFF    WIN
# 10919    3    8  21        12.0  61        12.0   True
# 10950    1   19  32        -4.0  68         4.0  False
# 10971    2   12  25         4.0  67         4.0   True
# 10990    2   14  21       -11.0  53        11.0  False
# 11019    3   14  22        21.0  74        21.0   True
# ...    ...  ...  ..         ...  ..         ...    ...
# 13094    5   17  19        -7.0  69         7.0  False
# 13117    4   11  19         7.0  67         7.0   True
# 13150    0   12  18       -13.0  79        13.0  False
# 13160    2    3  11       -10.0  63        10.0  False
# 13199    4   11  21        32.0  72        32.0   True
#
# [80 rows x 35 columns]

# %%
Pistons_Games.plot(x='GAME_DATE', y='PTS')
# Out:
# <Axes: xlabel='GAME_DATE'>

# %% [markdown]
# Correlation Analysis

# %%
NBA_Games.plot.scatter(x='AST', y='FGM')
# Out:
# <Axes: xlabel='AST', ylabel='FGM'>

# %%
import seaborn as sns
sns.regplot(x='AST', y='FGM', data=NBA_Games,  marker='.')
plt.xlabel('Assists')
plt.ylabel('Field Goals Made')
plt.title("Relationship between the Numbers of Assists and Field Goals Made", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Relationship between the Numbers of Assists and Field Goals Made')

# %% [markdown]
# Correlation Coefficient

# %%
NBA_Games['AST'].corr(NBA_Games['FGM'])
# Out:
# np.float64(0.6965185691036629)

# %%
sns.regplot(x='AST', y='FGA', data=NBA_Games,  marker='.')
plt.xlabel('Assists')
plt.ylabel('Field Goals Attempted')
plt.title("Relationship between the Numbers of Assists and Field Goals Attempted", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Relationship between the Numbers of Assists and Field Goals Attempted')

# %%
NBA_Games['AST'].corr(NBA_Games['FGA'])
# Out:
# np.float64(0.3580107833113529)

# %%
sns.lmplot(x='AST', y='FGA', hue='WL', data=NBA_Games)
plt.xlabel('Assists')
plt.ylabel('Field Goals Made')
plt.title("Relationship between the Numbers of Assists and Field Goals Made", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Relationship between the Numbers of Assists and Field Goals Made')

# %%
NBA_Games.corr(method='pearson', numeric_only=True)
# Out:
#                TEAM_ID  YEAR_FOUNDED  SEASON_ID   GAME_ID       MIN       PTS  \
# TEAM_ID       1.000000      0.159684  -0.028499 -0.004395  0.009351 -0.039739
# YEAR_FOUNDED  0.159684      1.000000  -0.007430  0.001668  0.004383 -0.023968
# SEASON_ID    -0.028499     -0.007430   1.000000 -0.017029  0.038428  0.001082
# GAME_ID      -0.004395      0.001668  -0.017029  1.000000 -0.795786 -0.385555
# MIN           0.009351      0.004383   0.038428 -0.795786  1.000000  0.426840
# PTS          -0.039739     -0.023968   0.001082 -0.385555  0.426840  1.000000
# FGM          -0.022654     -0.025650  -0.001468 -0.397515  0.419529  0.867683
# FGA          -0.015416     -0.057025  -0.011046 -0.425308  0.519493  0.450413
# FG_PCT       -0.014638      0.016595   0.008601 -0.159096  0.107260  0.687911
# FG3M         -0.113377     -0.080916   0.029134 -0.133298  0.147632  0.551357
# FG3A         -0.141702     -0.105705   0.033934 -0.091262  0.134381  0.330048
# FG3_PCT      -0.016195     -0.004177   0.007463 -0.107037  0.081386  0.461644
# FTM           0.022796      0.043878  -0.012781 -0.042625  0.085556  0.289037
# FTA           0.027864      0.022341  -0.026548 -0.008893  0.063729  0.228967
# FT_PCT       -0.012245      0.052001   0.025631 -0.084707  0.059872  0.184674
# OREB          0.036501     -0.034884  -0.007488 -0.021565  0.081987  0.015096
# DREB         -0.001342     -0.034135  -0.030477 -0.244214  0.295010  0.249265
# REB           0.019690     -0.048245  -0.029591 -0.215206  0.291852  0.215716
# AST          -0.099493     -0.071955  -0.037363 -0.357418  0.327648  0.645715
# STL          -0.012723     -0.025948  -0.071756  0.015759  0.009281  0.087527
# BLK           0.001869      0.005549   0.001645 -0.031720  0.062864  0.076797
# TOV          -0.029375     -0.092220  -0.148397  0.088664 -0.037703 -0.135769
# PF            0.009959     -0.044801  -0.033619  0.113199  0.004222  0.079831
# PLUS_MINUS   -0.000230      0.019938  -0.000098 -0.001348  0.002040  0.510800
# GM           -0.045124     -0.019812   0.002516 -0.328031  0.375849  0.951691
# POINT_DIFF   -0.006167     -0.025487   0.034086 -0.041346 -0.071876 -0.004586
# WIN          -0.005021      0.018298   0.000007 -0.000216  0.000905  0.411991
#
#                    FGM       FGA    FG_PCT      FG3M  ...       REB       AST  \
# TEAM_ID      -0.022654 -0.015416 -0.014638 -0.113377  ...  0.019690 -0.099493
# YEAR_FOUNDED -0.025650 -0.057025  0.016595 -0.080916  ... -0.048245 -0.071955
# SEASON_ID    -0.001468 -0.011046  0.008601  0.029134  ... -0.029591 -0.037363
# GAME_ID      -0.397515 -0.425308 -0.159096 -0.133298  ... -0.215206 -0.357418
# MIN           0.419529  0.519493  0.107260  0.147632  ...  0.291852  0.327648
# PTS           0.867683  0.450413  0.687911  0.551357  ...  0.215716  0.645715
# FGM           1.000000  0.567172  0.752900  0.386788  ...  0.203973  0.696519
# FGA           0.567172  1.000000 -0.108339  0.210054  ...  0.483507  0.358011
# FG_PCT        0.752900 -0.108339  1.000000  0.297176  ... -0.134207  0.553814
# FG3M          0.386788  0.210054  0.297176  1.000000  ...  0.053721  0.455304
# FG3A          0.189092  0.352338 -0.054533  0.758875  ...  0.145993  0.270667
# FG3_PCT       0.369696 -0.060742  0.498434  0.666344  ... -0.077870  0.383332
# FTM          -0.154558 -0.175785 -0.042105 -0.098478  ...  0.071156 -0.129175
# FTA          -0.179234 -0.192247 -0.059235 -0.118562  ...  0.091932 -0.152455
# FT_PCT        0.036479  0.008677  0.038437  0.032590  ... -0.037915  0.036919
# OREB          0.024390  0.457630 -0.331032 -0.107732  ...  0.556596 -0.083991
# DREB          0.228756  0.267987  0.065561  0.138558  ...  0.821711  0.212748
# REB           0.203973  0.483507 -0.134207  0.053721  ...  1.000000  0.128897
# AST           0.696519  0.358011  0.553814  0.455304  ...  0.128897  1.000000
# STL           0.075070  0.097593  0.010608  0.001757  ... -0.118250  0.075061
# BLK           0.077765  0.052087  0.051534  0.014574  ...  0.182747  0.090847
# TOV          -0.173950 -0.290790  0.021360 -0.035839  ...  0.098495 -0.069542
# PF           -0.021522 -0.004342 -0.024364  0.009143  ... -0.010509 -0.058044
# PLUS_MINUS    0.455110  0.010156  0.537798  0.314799  ...  0.324848  0.377541
# GM            0.673122  0.319723  0.558314  0.581310  ...  0.194918  0.530368
# POINT_DIFF    0.030095 -0.008601  0.039784  0.041768  ... -0.012793  0.083065
# WIN           0.345159 -0.034392  0.442808  0.229511  ...  0.255627  0.288407
#
#                    STL       BLK       TOV        PF  PLUS_MINUS        GM  \
# TEAM_ID      -0.012723  0.001869 -0.029375  0.009959   -0.000230 -0.045124
# YEAR_FOUNDED -0.025948  0.005549 -0.092220 -0.044801    0.019938 -0.019812
# SEASON_ID    -0.071756  0.001645 -0.148397 -0.033619   -0.000098  0.002516
# GAME_ID       0.015759 -0.031720  0.088664  0.113199   -0.001348 -0.328031
# MIN           0.009281  0.062864 -0.037703  0.004222    0.002040  0.375849
# PTS           0.087527  0.076797 -0.135769  0.079831    0.510800  0.951691
# FGM           0.075070  0.077765 -0.173950 -0.021522    0.455110  0.673122
# FGA           0.097593  0.052087 -0.290790 -0.004342    0.010156  0.319723
# FG_PCT        0.010608  0.051534  0.021360 -0.024364    0.537798  0.558314
# FG3M          0.001757  0.014574 -0.035839  0.009143    0.314799  0.581310
# FG3A          0.032203  0.011039 -0.046820  0.030102    0.070838  0.374195
# FG3_PCT      -0.029102  0.007817 -0.004600 -0.019259    0.385708  0.458407
# FTM           0.055602  0.018518  0.041629  0.214236    0.104961  0.525449
# FTA           0.071859  0.022939  0.062648  0.242506    0.063806  0.451328
# FT_PCT       -0.023640 -0.000505 -0.041403 -0.033095    0.120944  0.252196
# OREB          0.024804  0.003202  0.028897  0.051179   -0.015132  0.007392
# DREB         -0.159332  0.217745  0.098718 -0.047755    0.401344  0.229519
# REB          -0.118250  0.182747  0.098495 -0.010509    0.324848  0.194918
# AST           0.075061  0.090847 -0.069542 -0.058044    0.377541  0.530368
# STL           1.000000  0.001597  0.129524  0.047723    0.162410  0.083840
# BLK           0.001597  1.000000  0.041792  0.010336    0.179794  0.066213
# TOV           0.129524  0.041792  1.000000  0.219995   -0.128621 -0.094530
# PF            0.047723  0.010336  0.219995  1.000000   -0.052164  0.132052
# PLUS_MINUS    0.162410  0.179794 -0.128621 -0.052164    1.000000  0.478775
# GM            0.083840  0.066213 -0.094530  0.132052    0.478775  1.000000
# POINT_DIFF    0.040090 -0.030528  0.016139 -0.110580    0.001901 -0.025411
# WIN           0.134071  0.164220 -0.110268 -0.103020    0.805278  0.399696
#
#               POINT_DIFF       WIN
# TEAM_ID        -0.006167 -0.005021
# YEAR_FOUNDED   -0.025487  0.018298
# SEASON_ID       0.034086  0.000007
# GAME_ID        -0.041346 -0.000216
# MIN            -0.071876  0.000905
# PTS            -0.004586  0.411991
# FGM             0.030095  0.345159
# FGA            -0.008601 -0.034392
# FG_PCT          0.039784  0.442808
# FG3M            0.041768  0.229511
# FG3A            0.021652  0.017115
# FG3_PCT         0.025043  0.319531
# FTM            -0.092309  0.140648
# FTA            -0.091060  0.111220
# FT_PCT         -0.018274  0.096087
# OREB           -0.041755 -0.033558
# DREB            0.013246  0.330675
# REB            -0.012793  0.255627
# AST             0.083065  0.288407
# STL             0.040090  0.134071
# BLK            -0.030528  0.164220
# TOV             0.016139 -0.110268
# PF             -0.110580 -0.103020
# PLUS_MINUS      0.001901  0.805278
# GM             -0.025411  0.399696
# POINT_DIFF      1.000000  0.001514
# WIN             0.001514  1.000000
#
# [27 rows x 27 columns]
